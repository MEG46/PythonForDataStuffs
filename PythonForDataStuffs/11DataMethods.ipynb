# %%
import numpy as np
import pandas as pd
def brutToNet(price):
    return 10 * float(price)

teams = ["Fenerbahce","Fenerbahce","Fenerbahce","Fenerbahce","Fenerbahce","Fenerbahce","Fenerbahce","Fenerbahce","Fenerbahce","Fenerbahce","Fenerbahce","Galatasaray","Galatasaray","Galatasaray","Galatasaray","Galatasaray","Galatasaray","Galatasaray","Galatasaray","Galatasaray","Galatasaray","Galatasaray"]
players = ["A.Bayindir","Serdar","G.Vernes","A.Szalai","B.Osayi-Samuel","M.Crespo","W.Arao","F.Kadioglu","D.Rossi","J.King","M.Batshuayi","F.Muslera","L.Dubios","A.Bardakci","V.Nelsson","S.Boey","B.Kutlu","S.Oliveira","K.Akturkoglu","D.Mertens","M.Rashica","B.Yilmaz"]
table = list(zip(teams,players))
tables = pd.MultiIndex.from_tuples(table)
traits = [["Goalkeeper",24,5.9],["Center-Back",32,5.4],["Center-Back",29,5.7],["Center-Back",24,6.4],["Right-Back",25,5.9],["Center-Middlefield",26,5.9],["Center-Middlefield",30,5.8],["Left-Back",23,6.5],["Left-Winger",24,5.8],["Right-Winger",31,5.9],["Center-Forward",29,5.9],["Goalkeeper",36,9.2],["Left-Back",28,7.9],["Center-Back",28,7.7],["Center-Back",24,8.4],["Right-Back",22,7.9],["Center-Middlefield",24,7.9],["Center-Middlefield",30,8.8],["Left-Winger",24,8.8],["Attacking Middlefield",35,8.4],["Right-Winger",26,8.5],["Center-Forward",22,7.9]]
playernp = np.array(traits)
dataFrame = pd.DataFrame(playernp,index=tables,columns=["Role","Age","Rating"])
print("Recurrent Rating")
print()
print(dataFrame["Rating"].unique())
print()
print("Number Of Recurrent Rating")
print()
print(dataFrame["Rating"].nunique())
print()
print("Recurrent Numbers Of Rating")
print()
print(dataFrame["Rating"].value_counts())
print()
print("Rating (Over 100)")
print()
print(dataFrame["Rating"].apply(brutToNet))
print()
print("Is Rating Null?")
print()
print(dataFrame["Rating"].isnull())
# Out:
# Recurrent Rating
#
# ['5.9' '5.4' '5.7' '6.4' '5.8' '6.5' '9.2' '7.9' '7.7' '8.4' '8.8' '8.5']
#
# Number Of Recurrent Rating
#
# 12
#
# Recurrent Numbers Of Rating
#
# 5.9    5
# 7.9    4
# 5.8    2
# 8.4    2
# 8.8    2
# 5.4    1
# 5.7    1
# 6.4    1
# 6.5    1
# 9.2    1
# 7.7    1
# 8.5    1
# Name: Rating, dtype: int64
#
# Rating (Over 100)
#
# Fenerbahce   A.Bayindir        59.0
#              Serdar            54.0
#              G.Vernes          57.0
#              A.Szalai          64.0
#              B.Osayi-Samuel    59.0
#              M.Crespo          59.0
#              W.Arao            58.0
#              F.Kadioglu        65.0
#              D.Rossi           58.0
#              J.King            59.0
#              M.Batshuayi       59.0
# Galatasaray  F.Muslera         92.0
#              L.Dubios          79.0
#              A.Bardakci        77.0
#              V.Nelsson         84.0
#              S.Boey            79.0
#              B.Kutlu           79.0
#              S.Oliveira        88.0
#              K.Akturkoglu      88.0
#              D.Mertens         84.0
#              M.Rashica         85.0
#              B.Yilmaz          79.0
# Name: Rating, dtype: float64
#
# Is Rating Null?
#
# Fenerbahce   A.Bayindir        False
#              Serdar            False
#              G.Vernes          False
#              A.Szalai          False
#              B.Osayi-Samuel    False
#              M.Crespo          False
#              W.Arao            False
#              F.Kadioglu        False
#              D.Rossi           False
#              J.King            False
#              M.Batshuayi       False
# Galatasaray  F.Muslera         False
#              L.Dubios          False
#              A.Bardakci        False
#              V.Nelsson         False
#              S.Boey            False
#              B.Kutlu           False
#              S.Oliveira        False
#              K.Akturkoglu      False
#              D.Mertens         False
#              M.Rashica         False
#              B.Yilmaz          False
# Name: Rating, dtype: bool
