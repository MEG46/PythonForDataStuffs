# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.linspace(0,10,20)
data1 = data ** 3
(myFigure,myAxis) = plt.subplots(nrows=1,ncols=2)

for i in myAxis:
    i.plot(data,data1)
    i.set_xlabel("X Axis")
plt.tight_layout()
