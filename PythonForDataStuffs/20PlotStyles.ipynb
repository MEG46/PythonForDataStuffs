# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.linspace(0,12,24)
data1 = data ** 2
plt.title("Scatter Table")
plt.scatter(data,data1)

# %%
data = np.random.randint(0,100,50)
plt.title("Histogram Table")
plt.hist(data)
# Out:
# (array([6., 1., 4., 7., 7., 2., 7., 8., 4., 4.]),
#  array([ 0. ,  9.7, 19.4, 29.1, 38.8, 48.5, 58.2, 67.9, 77.6, 87.3, 97. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.title("Boxplot Table")
plt.boxplot(data*2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1da747b5fa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1da747c5580>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1da747b5cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1da747c5b20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1da747c5df0>],
#  'means': []}
